# %%
from MC.water_cylinder import run_MC, run_MC_fast_chunked
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d

L = 15.0  # half-length of cylinder in cm
Rs = [5.0, 10.0, 15.0]  # cylinder radii in cm
N_annihilations = 10
random_seed = 42

for R in Rs:
    print(f'Running MC simulation for cylinder radius R={R} cm')
    out = run_MC_fast_chunked(
        n_annihilations=N_annihilations,
        cylinder_radius_cm=R,
        cylinder_half_len_cm=L,
        rng_seed=random_seed,
        show_progress=True,
        out_dir ='../results/MC_data'
    )
# Out:
# Running MC simulation for cylinder radius R=5.0 cm
# Simulating chunks: 100%|██████████| 1/1 [00:00<00:00, 134.11it/s]
# Running MC simulation for cylinder radius R=10.0 cm
# Simulating chunks: 100%|██████████| 1/1 [00:00<00:00, 131.82it/s]
# Running MC simulation for cylinder radius R=15.0 cm
# Simulating chunks: 100%|██████████| 1/1 [00:00<00:00, 127.90it/s]
